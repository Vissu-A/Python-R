# %% [markdown]
# ### Index

# %% [markdown]
# 0. Introduction and Advantages of python
# 1. How to install python
# 2. Programming modes in python
# > 2.1 Interactive Mode<br>
# > 2.2 Scripting Mode<br>
# > How to execute / run python script
# 3. What is identifier
# 4. What is literal
# 5. What is variable
# 6. Rules to define a Variable
# > 6.1 No special charecters are allowed except underscore(_)<br>
# > 6.2 Must start with alphabet or underscore only.<br>
# > 6.3 should not start with digit.<br>
# > 6.4 should not use reserved / built-in keywords. help("keywords") ==> gives the list of all built-in keywords<br>
#
# Memory allocation<br>
# > different values for different variable<br>
# > same value for different variable<br>
# > built-in function "id()" to know the memeory location<br>
#
# 7. Data types
#
# > 7.1 Non-sequential Data types<br>
# >> 7.1.1 Int<br>
# >> 7.1.2 Float<br>
# >> 7.1.3 Complex<br>
# >> 7.1.4 Boolean(Bool)<br>
#
# > 7.2 Sequentialv Data types<br>
# >> 7.2.1 List<br>
# >> 7.2.2 Set<br>
# >> 7.2.3 Tuple<br>
# >> 7.2.4 Dict<br>
# >> 7.2.5 String(Str)<br>
# >> 7.2.6 Frozen set<br>
# >> 7.2.7 Ordered Dict<br>
#
# 8. Non-Sequential Data types
# 9. Type casting
# 10. Comments in python
# 11. Sequential Data types
# > String<br>
# > 11.1 How to define a string.<br>
# > 11.2 Escape Charecter.<br>
# > 11.3 Multiple sentances in single line(Line continution).<br>
# > 11.3 String functions/methods.<br>
# > 11.4 String concatination.<br>
#
# How to read/take input from user<br>
# > in python 2.x<br>
# >> input<br>
# >> raw_input<br>
#
# > in python 3.x
# >> input<br>
#
# 12. Operators
# > 12.1 Arithmetic operators<br>
# > 12.2 Comparison operators<br>
# > 12.3 Assignment operators<br>
# > 12.4 Logical operators<br>
# > 12.5 Identity operators<br>
# > 12.6 Membership operators<br>
# > 12.7 Bitwise operators<br>
# 13. Conditional statements<br>
# > 13.1 if<br>
# > 13.2 multiple if statements and draw back<br>
# > 13.3 elif statement to overcome drawback<br>
# > 13.4 else statement<br>
# > 13.5 nested if statements<br>
# > 13.6 Ternary operator<br>
#
# Switch case statement<br>
# range and xrange(python2.7) functions<br>
# 14. Iterative statements / Loops<br>
# > While, do-while<br>
# > While - else<br>
# > for<br>
# > for - else
#
# 15. Transfer / Control statements
# 16. Sequential Data types
# > What is mutable data type and What is im-mutable data type<br>
# > 16.1 List<br>
# > 16.2 Tuple<br>
# > 16.3 Set<br>
# > 16.4 Dict<br>
# > 16.7 String<br>
#
# How to assign same value to multiple variables.a = b = c = 5
# 17. packing and unpacking
# > 17.1 How to assign multiple values to single variable(Packing)<br>
# > 17.2 How to assign multiple values to multiple variables(Un-Packing)<br>
# 18. Copy, shallow copy, deep copy
# 19. Functions
# > 19.1 How to define a function<br>
# > 19.2 How to call a function<br>
# > 19.3 Global variable and Local Variable<br>
# > 19.4 Types of arguments<br>
# > 19.5 How to return value a function<br>
# > 19.6 inner functions/nested functions<br>
# > 19.7 Generator object(yield)<br>
# > 19.8 Recursive funtion<br>
# > 19.9 Global keyword<br>
# > 20 lamda function
# > 20.1 map, filter, reduce<br>
# 18. Higher order functions / nested functions
# 19. Decorators
# 20. Working with Text File<br>
# 21. Working with CSV File<br>
# 22. Working with JSON Data<br>
# 23. What is a module and package, How to create a module and , How to install a module, How to import a module, How to uninstall a module
# 24. How to connect to databases using python?
# 25. How to read data from databases using python programming?
#
# **Advanced - OOP(Object Oriented Programming)**
# 1. What is a class and object.
# 2. How to define class and create object for the class?
# 3. What is a constructure and how to create it?
# 4. Encapsulation
# > Access specifiers and modifiers
# 5. Abstration
# > Abstract classes<br>
# > interfaces
# 6. Ploymorphism
# > method overloading<br>
# > method overriding
# 7. Inheritance
# > what is the use of inhertiance and why we need to use it?<br>
# > types of inheritance<br>
# > practical example for each inheritance type<br>
# 8. Ecxeption Handling
# > what are exceptions<br>
# > How to handle exceptions gracefully?<br>
# > how to raise exceptions?<br>
# > How to write custom/user-definied exceptions.<br>
# 9. types of methods in oops(instance, class, static)
# 10. Threading
# 11. GIL(Global Interpriter Lock)
# 12. Singleton class

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               def                 if                  raise
# None                del                 import              return
# True                elif                in                  try
# and                 else                is                  while
# as                  except              lambda              with
# assert              finally             nonlocal            yield
# break               for                 not
# class               from                or
# continue            global              pass
