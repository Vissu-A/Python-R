# %%
# Importing Required Modules

import pandas as pd
import re
import nltk
import textblob

# %%
# Loading Data into DataFrame

df = pd.read_csv(r'C:\Users\vadapala\Desktop\pythonex\Glencore\Glencore_review_copy.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                       review title  \
# 0           0               cooperative and diverse environment,
# 1           1                                   Ambiente Laboral
# 2           2                            Dynamisches Unternehmen
# 3           3  Production driven company promoting entreprene...
# 4           4                                Glencore Experience
#
#                        job title                            job location  \
# 0      Sales Support Coordinator                                      IN
# 1  Coordinador Comercio Exterior  Montevideo, Departamento de Montevideo
# 2                          Legal                                Baar, ZG
# 3              Resident Engineer                           Kroondal mine
# 4                    Tax Analyst                            Stamford, CT
#
#                 date                                        description  \
# ...

# %%
desc = df['description']

# %%
desc
# Out:
# 0      Devising the new sales product i.e. CHR (Commo...
# 1      Mucha rotacion de personal, actualmente cuenta...
# 2      Sehr flache Hierarchie, Viel Spielraum um Ents...
# 3      Typical day - Start at 06H00 by first going th...
# 4      Glencore is a successful physical commodities ...
# 5      Det var bra HMS og bra betalt. Bra felleskap o...
# 6      A wonderful place to work with, Safety standar...
# 7      There ethic was a fair days work for a fair da...
# 8      Working conditions and overall culture is unpl...
# 9      Glencore is a firm believer in casualisation o...
# 10     Good working experience and working with peopl...
# 11     Le directeur des ressources humaines dans cett...
# 12     A good place to learn, unhealthy environment, ...
# 13     columbus has a good plant to learn from also h...
# 14     Glencore is a trader driven company with very ...
# 15     A very good company to work for with a strong ...
# ...

# %%
sen = []
for text in desc:
    for s in nltk.sent_tokenize(text):
        sen.append(s)
        print(s)
        print(type(s))

# sen
# Out:
# Devising the new sales product i.e.
# <class 'str'>
# CHR (Commodity Health Report)& selling the same to new & existing clients.
# <class 'str'>
# I have learned that changing the way of selling changes the mind of buyers, Management supported me with this new idea & allowed me to present the same to existing customers, The support reflects the teamwork and motivation that i got from my mates, Hardest part of my job was to get the approvals from my manager for final negotiation with clients.Most enjoyable part was interacting with ppl - customers, internal teammates, seniors, vendors on day today basis, learning something new on daily basis.
# <class 'str'>
# Mucha rotacion de personal, actualmente cuenta con muchos menos empleados debido a la mala gestion de la empresa.
# <class 'str'>
# Sehr flache Hierarchie, Viel Spielraum um Entscheidungen selber zu treffen, Proaktives arbeiten, Dynamisches Umfeld, International und Multikulturell
# <class 'str'>
# ...
