# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd

df = pd.read_csv(r"C:\Users\vadapala\Downloads\10times\USA_Exhibitor_url.csv")

print(df)

# driver = webdriver.Firefox(executable_path = r'D:\Downloads\geckodriver.exe')
#         driver.get(url)

#         elem = driver.find_element_by_link_text('CONTACT US')

#         print(elem)
        
#     else:
#         print('Not A Url')
        
        
# elem.clear()
# elem.send_keys("pycon")
# elem.send_keys(Keys.RETURN)
# assert "No results found." not in driver.page_source
# driver.close()
# Out:
#     Unnamed: 0                             Exhbitor Name  \
# 0            0                                 Tsi Group
# 1            1               Sunwin Stevia International
# 2            2        Shanghai Dj Creative International
# 3            3           Shandong Yuxin Bio-Tech Co.,Ltd
# 4            4     Shandong Shengxiangyuan Biotechnology
# 5            5      Shandong Longda Bio-Products Co.,Ltd
# 6            6           Shandong Baisheng Biotechnology
# 7            7            Rousselot- Darling Ingredients
# 8            8                     Ricebran Technologies
# 9            9                              Renewal Mill
# 10          10  Qingdao Super Evergreen Imp&Exp Co., Ltd
# 11          11  Qingdao Shengda Commercial&Trade Co.,Ltd
# 12          12                      Plt Health Solutions
# 13          13                              Planetarians
# 14          14                       Pharmhe Global Corp
# 15          15                                  Pennakem
# 16          16                      Nutraceuticals World
# 17          17                     Molinos Asociados Sac
# 18          18                          Milne Microdried
# 19          19                   Liverd Pharma Co., Tld.
# 20          20         Jiangsu Conat Biological Products
# 21          21                             Innophos Inc.
# 22          22     Inner Mongolia Rejuve Biotech Co.,Ltd
# 23          23                           Improved Nature
# 24          24               Gold Coast Ingredients Inc.
# 25          25              Food & Drink Business Europe
# 26          26              Etter Seed & Processing Ltd.
# 27          27           Baoji Oasier Bio-Tech Co., Ltd.
# 28          28                                   Balchem
# 29          29                 Aloe Jaumave S.A. De C.V.
# 30          30                                Alaskomega
# 31          31                                   Agropur
# 32          32                  Agri-Mark Dairy Proteins
#
#                                     Url
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7              http://www.rousselot.com
# 8           http://www.ricebrantech.com
# 9            http://www.renewalmill.com
# 10                                  NaN
# 11                                  NaN
# 12             http://www.plthealth.com
# 13          http://www.planetarians.com
# 14               http://www.pharmhe.com
# 15              http://www.pennakem.com
# 16                                  NaN
# 17      http://www.molinosasociados.com
# 18            http://www.milnefruit.com
# 19            http://www.biozymeusa.com
# 20                                  NaN
# 21              http://www.innophos.com
# 22                                  NaN
# 23        http://www.improvednature.com
# 24          http://www.goldcoastinc.com
# 25            http://www.fdbusiness.com
# 26             http://www.etterseed.com
# 27                                  NaN
# 28                                  NaN
# 29           http://www.aloejaumave.com
# 30            http://www.alaskomega.com
# 31    http://www.agropuringredients.com
# 32  http://www.agrimarkwheyproteins.com
